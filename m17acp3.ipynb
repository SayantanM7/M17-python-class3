# %% [markdown]
# **Uppercase and lowercase**

# %%
message=input("Enter your message in lowercase ")
print("Your message in uppercase is ", message.upper())
# Out:
# Enter your message in lowercase  i love codingal
# Your message in uppercase is  I LOVE CODINGAL
